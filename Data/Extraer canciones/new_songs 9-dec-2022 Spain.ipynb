# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth

# %%
auth_manager = SpotifyClientCredentials('74c040f7ab8049648ec083fdadfc1ddb','a9fa947f1cde460bb37b94060380a6cb')
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
playlist_9_dec = 'https://open.spotify.com/playlist/37i9dQZF1DX6PYajiT4pAf'

# %%
play = sp.playlist_tracks(playlist_9_dec, fields=None, limit=100,\
                          offset=0, market=None, additional_types=('track', 'episode'))

# %%
links_track = []
for e in (play['items']):
    links_track.append(e['track']['external_urls']['spotify'])

# %%
audio_features = []
for e in links_track:
    audio_features.append(sp.audio_features(e))

# %%
track_song = []

for e in (play['items']):
    track_song.append(e['track']['name'])

# %%
track_song
# Out:
# ['LA NENA DE ARGENTINA',
#  'La Máquina',
#  'Mala Mala',
#  'La Vida Es Una (From Puss in Boots: The Last Wish)',
#  'Infeliz',
#  'Otra Vez',
#  'YO QUE NO LLORO NUNCA, SIEMPRE QUE LLORAS TE LLORO',
#  'Je le savais',
#  'Figo',
#  'Nobody Gets Me',
#  'Ojitos Lindos',
#  'Me Rehúso',
#  'Booty Puty',
#  'KU LO SA (with Camila Cabello)',
#  'Young Pirri',
#  'Gibraltar',
#  'Entre Tú y Yo',
#  'Quasi',
#  "Did you know that there's a tunnel under Ocean Blvd",
#  'Back To You',
#  'Hero',
#  'Apariencias',
#  'Llorando Perdones',
#  '3 y Pico',
#  'Nuevo',
#  'Apreton',
#  'Viaje Pal Pasado',
#  'Alma y Libertad',
#  'El Mundo en Nuestro Sitio',
#  'Vivir El Momento',
#  'ReEVOLUCIÓN',
#  'Muero de Amor',
#  'Contigo',
#  'KDERONA',
#  '¿Por Qué?',
#  'Me Gusta',
#  'APOCALIPSI',
#  'No hay Patron',
#  'PA ENTRAR A VIVIR',
#  'Solos Tu y Yo',
#  'Un Mundo de Colores',
#  'Cuánto tiempo queda',
#  'hasta el fin...',
#  'Del cielo',
#  'Corazón Roto',
#  'soy MUY fan']

# %%
artist_name = []

for e in (play['items']):
    artist_name.append(e['track']['album']['artists'][0]['name'])

# %%
audio_features=[e[0] for e in audio_features]

# %%
datos_spotipy = pd.DataFrame(audio_features)

# %%
datos_spotipy.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.531   0.580    5    -4.688     0       0.1880        0.0984
# 1         0.799   0.775   11    -5.869     1       0.0770        0.0308
# 2         0.797   0.898   11    -4.617     1       0.0414        0.0415
# 3         0.819   0.777   10    -7.156     0       0.0513        0.0708
# 4         0.772   0.838    9    -4.425     1       0.1070        0.0261
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000201    0.1010    0.887  169.865  audio_features
# 1          0.005260    0.3090    0.605   95.027  audio_features
# 2          0.004940    0.2660    0.667  120.043  audio_features
# 3          0.000358    0.0973    0.625  109.979  audio_features
# 4          0.000000    0.0758    0.874  136.166  audio_features
#
#                        id                                   uri  \
# 0  0Dl34Kegtc0y0m0oPhQfiI  spotify:track:0Dl34Kegtc0y0m0oPhQfiI
# 1  35ns1WEurw3MVlHJjHwNWQ  spotify:track:35ns1WEurw3MVlHJjHwNWQ
# 2  3L7xk3OegOjSmBSJ6P0W7g  spotify:track:3L7xk3OegOjSmBSJ6P0W7g
# 3  35HgzqAoEZ28Ovq7kb9nDz  spotify:track:35HgzqAoEZ28Ovq7kb9nDz
# 4  2HL4l4HBlM5FlqmBycMEDR  spotify:track:2HL4l4HBlM5FlqmBycMEDR
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/0Dl34Kegtc0y...
# 1  https://api.spotify.com/v1/tracks/35ns1WEurw3M...
# 2  https://api.spotify.com/v1/tracks/3L7xk3OegOjS...
# 3  https://api.spotify.com/v1/tracks/35HgzqAoEZ28...
# 4  https://api.spotify.com/v1/tracks/2HL4l4HBlM5F...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/0Dl3...       151988
# 1  https://api.spotify.com/v1/audio-analysis/35ns...       296907
# 2  https://api.spotify.com/v1/audio-analysis/3L7x...       152000
# 3  https://api.spotify.com/v1/audio-analysis/35Hg...       189838
# 4  https://api.spotify.com/v1/audio-analysis/2HL4...       172941
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
datos_spotipy['artist_name'] = artist_name

# %%
datos_spotipy['track_name'] = track_song

# %%
datos_spotipy_mal = datos_spotipy[['type','id','uri','track_href','analysis_url','time_signature','key','mode']]

# %%
datos_spotipy.drop(['type','id','uri','track_href','analysis_url','time_signature','key','mode'],axis=1, inplace=True)

# %%
datos_spotipy.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.531   0.580    -4.688       0.1880        0.0984
# 1         0.799   0.775    -5.869       0.0770        0.0308
# 2         0.797   0.898    -4.617       0.0414        0.0415
# 3         0.819   0.777    -7.156       0.0513        0.0708
# 4         0.772   0.838    -4.425       0.1070        0.0261
#
#    instrumentalness  liveness  valence    tempo  duration_ms  \
# 0          0.000201    0.1010    0.887  169.865       151988
# 1          0.005260    0.3090    0.605   95.027       296907
# 2          0.004940    0.2660    0.667  120.043       152000
# 3          0.000358    0.0973    0.625  109.979       189838
# 4          0.000000    0.0758    0.874  136.166       172941
#
#         artist_name                                         track_name
# 0     Maria Becerra                               LA NENA DE ARGENTINA
# 1          Anuel AA                                         La Máquina
# 2           Ptazeta                                          Mala Mala
# 3           KAROL G  La Vida Es Una (From Puss in Boots: The Last W...
# 4  Lennis Rodriguez                                            Infeliz

# %%
datos_spotipy=datos_spotipy.iloc[:, [10,11,1,0,2,4,3,6,7,8,9]]

# %%
datos_spotipy.head()
# Out:
#         artist_name                                         track_name  \
# 0     Maria Becerra                               LA NENA DE ARGENTINA
# 1          Anuel AA                                         La Máquina
# 2           Ptazeta                                          Mala Mala
# 3           KAROL G  La Vida Es Una (From Puss in Boots: The Last W...
# 4  Lennis Rodriguez                                            Infeliz
#
#    energy  danceability  loudness  acousticness  speechiness  liveness  \
# 0   0.580         0.531    -4.688        0.0984       0.1880    0.1010
# 1   0.775         0.799    -5.869        0.0308       0.0770    0.3090
# 2   0.898         0.797    -4.617        0.0415       0.0414    0.2660
# 3   0.777         0.819    -7.156        0.0708       0.0513    0.0973
# 4   0.838         0.772    -4.425        0.0261       0.1070    0.0758
#
#    valence    tempo  duration_ms
# 0    0.887  169.865       151988
# 1    0.605   95.027       296907
# 2    0.667  120.043       152000
# 3    0.625  109.979       189838
# 4    0.874  136.166       172941

# %%
datos_spotipy.rename(columns = {'duration_ms':'duration'}, inplace = True)

# %%
datos_spotipy['duration'] = (datos_spotipy['duration']/1000).round(2)

datos_spotipy.head()
# Out:
#         artist_name                                         track_name  \
# 0     Maria Becerra                               LA NENA DE ARGENTINA
# 1          Anuel AA                                         La Máquina
# 2           Ptazeta                                          Mala Mala
# 3           KAROL G  La Vida Es Una (From Puss in Boots: The Last W...
# 4  Lennis Rodriguez                                            Infeliz
#
#    energy  danceability  loudness  acousticness  speechiness  liveness  \
# 0   0.580         0.531    -4.688        0.0984       0.1880    0.1010
# 1   0.775         0.799    -5.869        0.0308       0.0770    0.3090
# 2   0.898         0.797    -4.617        0.0415       0.0414    0.2660
# 3   0.777         0.819    -7.156        0.0708       0.0513    0.0973
# 4   0.838         0.772    -4.425        0.0261       0.1070    0.0758
#
#    valence    tempo  duration
# 0    0.887  169.865    151.99
# 1    0.605   95.027    296.91
# 2    0.667  120.043    152.00
# 3    0.625  109.979    189.84
# 4    0.874  136.166    172.94

# %%
datos_spotipy.to_csv('../Proyecto-FInal-Spotify/CSV_full/data_week_9DEC_SPAIN.csv', index=False)
