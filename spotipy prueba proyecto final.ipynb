# %%
#%pip install spotipy

# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth

# %%
BORRAR AL FINAAAAAAAL
# Out:
#   Input In [2]
#     BORRAR AL FINAAAAAAAL
#            ^
# SyntaxError: invalid syntax

# %%
password = "a9fa947f1cde460bb37b94060380a6cb"

# %%
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id="74c040f7ab8049648ec083fdadfc1ddb",
                                               client_secret=password,
                                               redirect_uri="https://developer.spotify.com/dashboard/applications/74c040f7ab8049648ec083fdadfc1ddb",
                                               scope="user-library-read"))

# %% [markdown]
# # ESTO DE ABAJO ES LO QUE FUNCIONA PARA PODER USAR SPOTIPY

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials('74c040f7ab8049648ec083fdadfc1ddb','a9fa947f1cde460bb37b94060380a6cb')
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
playlists = sp.user_playlists('spotify')
while playlists:
    for i, playlist in enumerate(playlists['items']):
        print("%4d %s %s" % (i + 1 + playlists['offset'], playlist['uri'],  playlist['name']))
    if playlists['next']:
        playlists = sp.next(playlists)
    else:
        playlists = None

# %%
lz_uri = 'https://open.spotify.com/artist/7ltDVBr6mKbRvohxheJ9h1'

spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials('74c040f7ab8049648ec083fdadfc1ddb','a9fa947f1cde460bb37b94060380a6cb'))

results = spotify.artist_top_tracks(lz_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()

# %%
audio_features

# %%
import spotipy as sp
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials('74c040f7ab8049648ec083fdadfc1ddb','a9fa947f1cde460bb37b94060380a6cb'))

urn = 'spotify:artist:3jOstUTkEu2JkjvRdBA5Gu'
sp = spotify

artist = sp.artist(urn)
print(artist)

user = sp.user('plamere')
print(user)

# %%
sp.audio_features('https://open.spotify.com/album/5omNd3Mkij9C3ZeW19rRmv?highlight=spotify:track:5ildQOEKmJuWGl2vRkFdYc')

# %%
sp.audio_features('https://open.spotify.com/track/64BuLY7ggczC17w5LSUlSE')
# Out:
# [{'danceability': 0.713,
#   'energy': 0.611,
#   'key': 1,
#   'loudness': -5.993,
#   'mode': 0,
#   'speechiness': 0.0507,
#   'acousticness': 0.361,
#   'instrumentalness': 0,
#   'liveness': 0.0803,
#   'valence': 0.173,
#   'tempo': 97.936,
#   'type': 'audio_features',
#   'id': '64BuLY7ggczC17w5LSUlSE',
#   'uri': 'spotify:track:64BuLY7ggczC17w5LSUlSE',
#   'track_href': 'https://api.spotify.com/v1/tracks/64BuLY7ggczC17w5LSUlSE',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/64BuLY7ggczC17w5LSUlSE',
#   'duration_ms': 221520,
#   'time_signature': 4}]

# %%
sp.audio_features('https://open.spotify.com/track/6WU2eYUtOL91iROonROPyh')

# %%
sp.audio_analysis('https://open.spotify.com/track/6WU2eYUtOL91iROonROPyh')

# %%
sp.current_user_following_artists

# %%
sp.new_releases(country='ES')

# %%
sp.tracks('https://open.spotify.com/playlist/37i9dQZF1DX6PYajiT4pAf')

# %%
sp.user('javi1025')

# %%
sp.user_playlist_create('raulmartin525', 'prueba', public=True, collaborative=False, description='estoesunaprueba')

# %%
spotify = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials('74c040f7ab8049648ec083fdadfc1ddb','a9fa947f1cde460bb37b94060380a6cb'))

# %%
playlist_id = 'https://open.spotify.com/playlist/37i9dQZF1DX6PYajiT4pAf'

# %%
pepe = sp.playlist_tracks(playlist_id, fields=None, limit=100,\
                          offset=0, market=None, additional_types=('track', 'episode'))

# %%
pepe['items'][0]['track']['external_urls'].values()

# %%
links_track = []
for e in (pepe['items']):
    links_track.append(e['track']['external_urls']['spotify'])

# %%
links_track

# %%
pepe['items'][0]['track']['external_urls']['spotify']

# %%
audio_features = []
for e in links_track:
    audio_features.append(sp.audio_features(e))

# %%
audio_features

# %%
sp.audio_features('https://open.spotify.com/track/6WU2eYUtOL91iROonROPyh')

# %%
sp.audio_features('https://open.spotify.com/artist/4F4pp8NUW08JuXwnoxglpN')

# %%
for e in (pepe['items']):
    print(e['track']['external_urls'].values())

# %%
pepe['items'][0]['track'].keys()

# %%
pepe['items'][0]['track']['name']

# %%
track_song = []

for e in (pepe['items']):
    track_song.append(e['track']['name'])

# %%
track_song

# %%
artist_name = []

for e in (pepe['items']):
    artist_name.append(e['track']['album']['artists'][0]['name'])

# %%
audio_features[1]

# %%
for e in audio_features:
    print(e[0])

# %%
audio_features=[e[0] for e in audio_features]

audio_features[0]
# Out:
# {'danceability': 0.662,
#  'energy': 0.828,
#  'key': 9,
#  'loudness': -5.854,
#  'mode': 1,
#  'speechiness': 0.0821,
#  'acousticness': 0.148,
#  'instrumentalness': 0,
#  'liveness': 0.423,
#  'valence': 0.451,
#  'tempo': 113.039,
#  'type': 'audio_features',
#  'id': '6WU2eYUtOL91iROonROPyh',
#  'uri': 'spotify:track:6WU2eYUtOL91iROonROPyh',
#  'track_href': 'https://api.spotify.com/v1/tracks/6WU2eYUtOL91iROonROPyh',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6WU2eYUtOL91iROonROPyh',
#  'duration_ms': 191693,
#  'time_signature': 4}

# %%
datos_spotipy = pd.DataFrame(audio_features)

# %%
for e in audio_features:
    for d in e:
        df = pd.DataFrame([key for key in d.keys()], columns=['Name'])
        print(df)
        df['danceability'] = [value['danceability'] for value in d.values()]
        df['energy'] = [value['energy'] for value in d.values()]
        df['key'] = [value['key'] for value in d.values()]
        df['loudness'] = [value['loudness'] for value in d.values()]
        df['mode'] = [value['mode'] for value in d.values()]
        df['speechiness'] = [value['speechiness'] for value in d.values()]
        df['acousticness'] = [value['acousticness'] for value in d.values()]
        df['instrumentalness'] = [value['instrumentalness'] for value in d.values()]
        df['liveness'] = [value['liveness'] for value in d.values()]
        df['valence'] = [value['valence'] for value in d.values()]
        df['tempo'] = [value['tempo'] for value in d.values()]
        df['type'] = [value['type'] for value in d.values()]
        df['id'] = [value['id'] for value in d.values()]
        df['uri'] = [value['uri'] for value in d.values()]
        df['track_href'] = [value['track_href'] for value in d.values()]
        df['analysis_url'] = [value['analysis_url'] for value in d.values()]
        df['duration_ms'] = [value['duration_ms'] for value in d.values()]
        df['time_signature'] = [value['time_signature'] for value in d.values()]

# %%
datos_spotipy['artist_name'] = artist_name

# %%
datos_spotipy['track_name'] = track_song

# %%
datos_spotipy.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.662   0.828    9    -5.854     1       0.0821        0.1480
# 1         0.750   0.593    2    -5.736     1       0.1760        0.3720
# 2         0.713   0.703    8    -5.769     1       0.1940        0.2980
# 3         0.663   0.730    9    -5.829     0       0.0638        0.0886
# 4         0.743   0.831    8    -4.042     0       0.0584        0.1140
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000     0.423    0.451  113.039  audio_features
# 1          0.000595     0.108    0.454  179.962  audio_features
# 2          0.000000     0.321    0.576  123.060  audio_features
# 3          0.000000     0.211    0.774  135.102  audio_features
# 4          0.000064     0.350    0.609   95.975  audio_features
#
#                        id                                   uri  \
# 0  6WU2eYUtOL91iROonROPyh  spotify:track:6WU2eYUtOL91iROonROPyh
# ...

# %%
datos_spotipy_mal = datos_spotipy[['type','id','uri','track_href','analysis_url','time_signature','key','mode']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [31], in <cell line: 1>()
# ----> 1 datos_spotipy_mal = datos_spotipy[['type','id','uri','track_href','analysis_url','time_signature','key','mode']]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
# ...

# %%
datos_spotipy.drop(['type','id','uri','track_href','analysis_url','time_signature','key','mode'],axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 datos_spotipy.drop(['type','id','uri','track_href','analysis_url','time_signature','key','mode'],axis=1, inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
datos_spotipy.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.662   0.828    9    -5.854     1       0.0821        0.1480
# 1         0.750   0.593    2    -5.736     1       0.1760        0.3720
# 2         0.713   0.703    8    -5.769     1       0.1940        0.2980
# 3         0.663   0.730    9    -5.829     0       0.0638        0.0886
# 4         0.743   0.831    8    -4.042     0       0.0584        0.1140
#
#    instrumentalness  liveness  valence    tempo  duration_ms    artist_name  \
# 0          0.000000     0.423    0.451  113.039       191693       Bad Gyal
# 1          0.000595     0.108    0.454  179.962       216000           Rvfv
# 2          0.000000     0.321    0.576  123.060       255693       Arcángel
# 3          0.000000     0.211    0.774  135.102       217038  Pablo Alborán
# 4          0.000064     0.350    0.609   95.975       168133           Feid
#
#                    track_name
# 0                      Real G
# ...

# %%
play1 = 'https://open.spotify.com/playlist/37i9dQZF1DX18jTM2l2fJY'

# %%
p1 = sp.playlist_tracks(play1, fields=None, limit=100, offset=0, market=None,\
                        additional_types=('track', 'episode'))

# %%
p1['items'][0]['track']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/track/4LRPiXqCikLlN15c3yImP7'

# %%
links_track1 = []
for e in (p1['items']):
    links_track1.append(e['track']['external_urls']['spotify'])

# %%
audio_features1 = []
for e in links_track1:
    audio_features1.append(sp.audio_features(e))

# %%
track_song1 = []

for e in (p1['items']):
    track_song1.append(e['track']['name'])

# %%
artist_name1 = []

for e in (p1['items']):
    artist_name1.append(e['track']['album']['artists'][0]['name'])

# %%
artist_name1
# Out:
# ['Harry Styles',
#  'Glass Animals',
#  'The Kid LAROI',
#  'Bad Bunny',
#  'Bad Bunny',
#  'Elton John',
#  'Imagine Dragons',
#  'Bizarrap',
#  'Bad Bunny',
#  'Kate Bush',
#  'Lil Nas X',
#  'GAYLE',
#  'Bad Bunny',
#  'Justin Bieber',
#  'Joji',
#  'Bad Bunny',
#  'Ed Sheeran',
#  'Adele',
#  'Elley Duhé',
#  'Doja Cat',
#  'The Neighbourhood',
#  'Rauw Alejandro',
#  'Tom Odell',
#  'KAROL G',
#  'Camila Cabello',
#  'Jack Harlow',
#  'The Weeknd',
#  'Becky G',
#  'Lost Frequencies',
#  'Ed Sheeran',
#  'Farruko',
#  'Olivia Rodrigo',
#  'Ruth B.',
#  'Lizzo',
#  'Lil Nas X',
#  'OneRepublic',
#  'Coldplay',
#  'Manuel Turizo',
#  'Cris Mj',
#  'The Walters',
#  'Jaymes Young',
#  'Bad Bunny',
#  'Harry Styles',
#  'Tiësto',
#  'Olivia Rodrigo',
#  'Harry Styles',
#  'Stephen Sanchez',
#  'Tainy',
#  'Bad Bunny',
#  'Bad Bunny']

# %%
audio_features1=[e[0] for e in audio_features1]

# %%
datos_spotipy1 = pd.DataFrame(audio_features1)

# %%
play2='https://open.spotify.com/playlist/6TGxmQCgNUC3Q4OvmFO3Sd'

# %%
p2 = sp.playlist_tracks(play2, fields=None,  offset=0, market=None,additional_types=('track', 'episode'))

# %%
links_track2 = []
for e in (p2['items']):
    links_track2.append(e['track']['external_urls']['spotify'])

# %%
audio_features2 = []
for e in links_track2:
    audio_features2.append(sp.audio_features(e))

# %%
track_song2 = []

for e in (p2['items']):
    track_song2.append(e['track']['name'])

# %%
artist_name2 = []

for e in (p2['items']):
    artist_name2.append(e['track']['album']['artists'][0]['name'])

# %%
audio_features2=[e[0] for e in audio_features2]

datos_spotipy2 = pd.DataFrame(audio_features2)

# %%
datos_spotipy2.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.668   0.802    5    -4.005     0       0.0917        0.0273
# 1         0.520   0.731    6    -5.338     0       0.0557        0.3420
# 2         0.919   0.623    7    -6.521     1       0.0992        0.1840
# 3         0.780   0.689    7    -5.668     1       0.1410        0.0368
# 4         0.686   0.494    1    -7.093     1       0.0355        0.6130
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.1630    0.769  113.796  audio_features
# 1          0.001010    0.3110    0.662  173.930  audio_features
# 2          0.000016    0.0609    0.775  130.037  audio_features
# 3          0.000010    0.0698    0.642  115.042  audio_features
# 4          0.000058    0.4020    0.700  168.946  audio_features
#
#                        id                                   uri  \
# 0  6sZo5nJIsFWXefRCCexpx0  spotify:track:6sZo5nJIsFWXefRCCexpx0
# ...

# %%
play3='https://open.spotify.com/playlist/5iwkYfnHAGMEFLiHFFGnP4'

# %%
p3 = sp.playlist_tracks(play3, fields=None,limit=100,  offset=0, market=None,additional_types=('track', 'episode'))

# %%
links_track3 = []
for e in (p3['items']):
    links_track3.append(e['track']['external_urls']['spotify'])

# %%
audio_features3 = []
for e in links_track3:
    audio_features3.append(sp.audio_features(e))

# %%
track_song3 = []

for e in (p3['items']):
    track_song3.append(e['track']['name'])

# %%
artist_name3 = []

for e in (p3['items']):
    artist_name3.append(e['track']['album']['artists'][0]['name'])

# %%
audio_features3=[e[0] for e in audio_features3]

datos_spotipy3 = pd.DataFrame(audio_features3)

# %%
datos_spotipy3.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.561   0.965    7    -3.673     0       0.0343       0.00383
# 1         0.696   0.793    8    -5.733     1       0.0970       0.06830
# 2         0.637   0.643    4    -6.571     1       0.0519       0.13000
# 3         0.721   0.769    7    -4.111     1       0.1050       0.09220
# 4         0.695   0.540    4    -5.692     1       0.0493       0.29900
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000007    0.3710    0.304  128.040  audio_features
# 1          0.000004    0.1800    0.698  120.003  audio_features
# 2          0.000002    0.1420    0.533   97.008  audio_features
# 3          0.000000    0.0817    0.915  155.932  audio_features
# 4          0.000000    0.3670    0.415  121.932  audio_features
#
#                        id                                   uri  \
# 0  4uUG5RXrOk84mYEfFvj3cK  spotify:track:4uUG5RXrOk84mYEfFvj3cK
# ...

# %%
play4='https://open.spotify.com/playlist/4Rz4hMX9ONI0s0YHyJHkEL'

# %%
p4 = sp.playlist_tracks(play4, fields=None,limit=100,  offset=0, market=None,additional_types=('track', 'episode'))

# %%
links_track4 = []
for e in (p4['items']):
    links_track4.append(e['track']['external_urls']['spotify'])

# %%
audio_features4 = []
for e in links_track4:
    audio_features4.append(sp.audio_features(e))

# %%
track_song4 = []

for e in (p4['items']):
    track_song4.append(e['track']['name'])

# %%
artist_name4 = []

for e in (p4['items']):
    artist_name4.append(e['track']['album']['artists'][0]['name'])

# %%
audio_features4=[e[0] for e in audio_features4]

datos_spotipy4 = pd.DataFrame(audio_features4)

# %%
datos_spotipy4
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.714   0.472    2    -7.375     1       0.0864       0.01300
# 1          0.637   0.643    4    -6.571     1       0.0519       0.13000
# 2          0.561   0.965    7    -3.673     0       0.0343       0.00383
# 3          0.520   0.731    6    -5.338     0       0.0557       0.34200
# 4          0.465   0.260    0    -8.179     0       0.0310       0.47500
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.845   0.797    1    -4.984     1       0.1390       0.05820
# 96         0.788   0.859    2    -2.724     1       0.0856       0.28100
# 97         0.814   0.628    7    -7.178     1       0.2210       0.16700
# 98         0.498   0.872    2    -6.744     1       0.0977       0.14000
# 99         0.695   0.540    4    -5.692     1       0.0493       0.29900
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
datos_spotipy1['artist_name'] = artist_name1

# %%
datos_spotipy1['track_name'] = track_song1

# %%
#datos_spotipy_mal1 = datos_spotipy1[['type','id','uri','track_href','analysis_url','time_signature']]

# %%
datos_spotipy2['artist_name'] = artist_name2

# %%
datos_spotipy3['artist_name'] = artist_name3

# %%
datos_spotipy4['artist_name'] = artist_name4

# %%
datos_spotipy2['track_name'] = track_song2

# %%
datos_spotipy3['track_name'] = track_song3

# %%
datos_spotipy4['track_name'] = track_song4

# %%
spotify_2022 = pd.concat([datos_spotipy1, datos_spotipy2,datos_spotipy3,datos_spotipy4])

# %%
spotify_2022.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.520   0.731    6    -5.338     0       0.0557        0.3420
# 1         0.761   0.525   11    -6.900     1       0.0944        0.4400
# 2         0.591   0.764    1    -5.484     1       0.0483        0.0383
# 3         0.911   0.712    1    -5.105     0       0.0817        0.0901
# 4         0.650   0.715    5    -5.198     0       0.2530        0.0993
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.001010    0.3110    0.662  173.930  audio_features
# 1          0.000007    0.0921    0.531   80.870  audio_features
# 2          0.000000    0.1030    0.478  169.928  audio_features
# 3          0.000027    0.0933    0.425   92.005  audio_features
# 4          0.000291    0.1260    0.187  106.672  audio_features
#
#                        id                                   uri  \
# 0  4LRPiXqCikLlN15c3yImP7  spotify:track:4LRPiXqCikLlN15c3yImP7
# ...

# %%
datos_spotipy_2022mal = spotify_2022[['type','id','uri','track_href','analysis_url','time_signature','key','mode']]

# %%
spotify_2022.drop(['type','id','uri','track_href','analysis_url','time_signature','key','mode'],axis=1, inplace=True)

# %%
spotify_2022.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.520   0.731    -5.338       0.0557        0.3420
# 1         0.761   0.525    -6.900       0.0944        0.4400
# 2         0.591   0.764    -5.484       0.0483        0.0383
# 3         0.911   0.712    -5.105       0.0817        0.0901
# 4         0.650   0.715    -5.198       0.2530        0.0993
#
#    instrumentalness  liveness  valence    tempo  duration_ms    artist_name  \
# 0          0.001010    0.3110    0.662  173.930       167303   Harry Styles
# 1          0.000007    0.0921    0.531   80.870       238805  Glass Animals
# 2          0.000000    0.1030    0.478  169.928       141806  The Kid LAROI
# 3          0.000027    0.0933    0.425   92.005       178567      Bad Bunny
# 4          0.000291    0.1260    0.187  106.672       243717      Bad Bunny
#
#                   track_name
# 0                  As It Was
# 1                 Heat Waves
# 2  STAY (with Justin Bieber)
# ...

# %%
spotify_2022=spotify_2022.iloc[:, [10,11,1,0,2,4,3,6,7,8,9]]

# %%
spotify_2022
# Out:
#             artist_name                 track_name  energy  danceability  \
# 0          Harry Styles                  As It Was   0.731         0.520
# 1         Glass Animals                 Heat Waves   0.525         0.761
# 2         The Kid LAROI  STAY (with Justin Bieber)   0.764         0.591
# 3             Bad Bunny            Me Porto Bonito   0.712         0.911
# 4             Bad Bunny           Tití Me Preguntó   0.715         0.650
# ..                  ...                        ...     ...           ...
# 95              Imanbek               Belly Dancer   0.797         0.845
# 96           Ed Sheeran                    Shivers   0.859         0.788
# 97  Megan Thee Stallion               Sweetest Pie   0.628         0.814
# 98             Johnning              Said and Done   0.872         0.498
# 99                GAYLE                    abcdefu   0.540         0.695
#
#     loudness  acousticness  speechiness  liveness  valence    tempo  \
# ...

# %%
spotify_2022.drop_duplicates().shape==spotify_2022.shape
# Out:
# False

# %%
spotify_2022=spotify_2022.drop_duplicates()

# %%
spotify_2022.drop_duplicates().shape==spotify_2022.shape
# Out:
# True

# %%
len(spotify_2022)
# Out:
# 229

# %%
spotify_2022.to_csv('../Desktop/Proyecto-FInal-Spotify/Spoti/spotify_2022.csv')

# %%
len(spotify_2022)
# Out:
# 229

# %%
spotify_2022
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 spotify_2022
#
# NameError: name 'spotify_2022' is not defined
