# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth

# %%
auth_manager = SpotifyClientCredentials('74c040f7ab8049648ec083fdadfc1ddb','a9fa947f1cde460bb37b94060380a6cb')
sp = spotipy.Spotify(auth_manager=auth_manager)

# %% [markdown]
# # Quiero hacer que la funcion saque directamente un unico dataframe con un bucle dentro pero no tengo claro como hacerlo !!!! PREGUNTAR EL LUNES!!!

# %% [markdown]
# ## Importante 2018 y 2019 juntos en la misma playlist

# %%
playlist = [play_2000 ='https://open.spotify.com/playlist/37i9dQZF1DX4f5T2OF14nZ',\
            play_2001 = 'https://open.spotify.com/playlist/37i9dQZF1DX8ri0Q7eg1qe',\
           play_2002 ='https://open.spotify.com/playlist/37i9dQZF1DXag6GMMWZSZ4',\
           play_2003 ='https://open.spotify.com/playlist/37i9dQZF1DX8EdanpjeYXD',\
           play_2004 = 'https://open.spotify.com/playlist/37i9dQZF1DX25bh4Tsdtts',\
           play_2005 = 'https://open.spotify.com/playlist/37i9dQZF1DXax0Fz6Uds7a',\
           play_2006 = 'https://open.spotify.com/playlist/37i9dQZF1DX0ywbtKZmG0E',\
           play_2007 = 'https://open.spotify.com/playlist/37i9dQZF1DXdHJoK6pY7Oh',\
           play_2008 = 'https://open.spotify.com/playlist/37i9dQZF1DWVBAKsA3f6Ck',\
           play_2009 = 'https://open.spotify.com/playlist/37i9dQZF1DX1bd6S1wAnbF',\
           play_2010='https://open.spotify.com/playlist/37i9dQZF1DX9zzf8V7JAQ5',\
           play_2011='https://open.spotify.com/playlist/37i9dQZF1DWVqckwNwncJY',\
           play_2012='https://open.spotify.com/playlist/37i9dQZF1DX0rX3xBmXrDn',\
           play_2013='https://open.spotify.com/playlist/37i9dQZF1DX5aHrtH3szCF',\
           play_2014 = 'https://open.spotify.com/playlist/37i9dQZF1DX5S2RzqA1qg6',\
           play_2015='https://open.spotify.com/playlist/37i9dQZF1DXcpG5daApEnA',\
           play_2016='https://open.spotify.com/playlist/37i9dQZF1CyQp1mdXCYxpR',\
           play_2017='https://open.spotify.com/playlist/37i9dQZF1DXaslEeaHwWLL',\
           play_20182019='https://open.spotify.com/playlist/0sVCLfAbcXb8dKif9QP3Ch',\
           play_2020 = 'https://open.spotify.com/playlist/2ErDoKVlOJMP5xKxyKmD6U',\
           play_2021 = 'https://open.spotify.com/playlist/5tntLMmmuZiPB2d41VsS4P',\
           play_2022'https://open.spotify.com/playlist/37i9dQZF1DXdo9iIZiH7LB']

# %%
play_2000 ='https://open.spotify.com/playlist/37i9dQZF1DX4f5T2OF14nZ'
play_2001 = 'https://open.spotify.com/playlist/37i9dQZF1DX8ri0Q7eg1qe'
play_2002 ='https://open.spotify.com/playlist/37i9dQZF1DXag6GMMWZSZ4'
play_2003 ='https://open.spotify.com/playlist/37i9dQZF1DX8EdanpjeYXD'
play_2004 = 'https://open.spotify.com/playlist/37i9dQZF1DX25bh4Tsdtts'
play_2005 = 'https://open.spotify.com/playlist/37i9dQZF1DXax0Fz6Uds7a'
play_2006 = 'https://open.spotify.com/playlist/37i9dQZF1DX0ywbtKZmG0E'
play_2007 = 'https://open.spotify.com/playlist/37i9dQZF1DXdHJoK6pY7Oh'
play_2008 = 'https://open.spotify.com/playlist/37i9dQZF1DWVBAKsA3f6Ck'
play_2009 = 'https://open.spotify.com/playlist/37i9dQZF1DX1bd6S1wAnbF'
play_2010='https://open.spotify.com/playlist/37i9dQZF1DX9zzf8V7JAQ5'
play_2011='https://open.spotify.com/playlist/37i9dQZF1DWVqckwNwncJY'
play_2012='https://open.spotify.com/playlist/37i9dQZF1DX0rX3xBmXrDn'
play_2013='https://open.spotify.com/playlist/37i9dQZF1DX5aHrtH3szCF'
play_2014 = 'https://open.spotify.com/playlist/37i9dQZF1DX5S2RzqA1qg6'
play_2015='https://open.spotify.com/playlist/37i9dQZF1DXcpG5daApEnA'
play_2016='https://open.spotify.com/playlist/37i9dQZF1CyQp1mdXCYxpR'
play_2017='https://open.spotify.com/playlist/37i9dQZF1DXaslEeaHwWLL'
play_20182019='https://open.spotify.com/playlist/0sVCLfAbcXb8dKif9QP3Ch'
play_2020 = 'https://open.spotify.com/playlist/2ErDoKVlOJMP5xKxyKmD6U'
play_2021 = 'https://open.spotify.com/playlist/5tntLMmmuZiPB2d41VsS4P'
play_2022 = 'https://open.spotify.com/playlist/37i9dQZF1DXdo9iIZiH7LB'

# %%
def spoti_info(playlist):
    play = sp.playlist_tracks(playlist, fields=None, limit=100,\
                          offset=0, market=None, additional_types=('track', 'episode'))
    links_track = []
    for e in (play['items']):
        links_track.append(e['track']['external_urls']['spotify'])
    
    audio_features = []
    for e in links_track:
        audio_features.append(sp.audio_features(e))
    
    track_song = []
    for e in (play['items']):
        track_song.append(e['track']['name'])
    
    artist_name = []
    for e in (play['items']):
        artist_name.append(e['track']['album']['artists'][0]['name'])
    
    audio_features=[e[0] for e in audio_features]
    
    datos_spotipy = pd.DataFrame(audio_features)
    
    datos_spotipy['artist_name'] = artist_name
    
    datos_spotipy['track_name'] = track_song
    
    datos_spotipy.drop(['type','id','uri','track_href','analysis_url','time_signature','key','mode'],axis=1, inplace=True)
    
    datos_spotipy=datos_spotipy.iloc[:, [10,11,1,0,2,4,3,6,7,8,9]]
    
    datos_spotipy.rename(columns = {'duration_ms':'duration'}, inplace = True)
    
    datos_spotipy['duration'] = (datos_spotipy['duration']/1000).round(2)





    return datos_spotipy

# %%
p2000 = spoti_info(play_2000)

# %%
p2001 = spoti_info(play_2001)

# %%
p2002 = spoti_info(play_2002)

# %%
p2003 = spoti_info(play_2003)

# %%
p2004 = spoti_info(play_2004)

# %%
p2005 = spoti_info(play_2005)

# %%
p2006 = spoti_info(play_2006)

# %%
p2007 = spoti_info(play_2007)

# %%
p2008 = spoti_info(play_2008)

# %%
p2009 = spoti_info(play_2009)

# %%
p2010 = spoti_info(play_2010)

# %%
p2011 = spoti_info(play_2011)

# %%
p2012 = spoti_info(play_2012)

# %%
p2013 = spoti_info(play_2013)

# %%
p2014 = spoti_info(play_2014)

# %%
p2015 = spoti_info(play_2015)

# %%
p2016 = spoti_info(play_2016)

# %%
p2017 = spoti_info(play_2017)

# %%
p20182019 = spoti_info(play_20182019)

# %%
p2020 = spoti_info(play_2020)

# %%
p2021 = spoti_info(play_2021)

# %%
p2022 = spoti_info(play_2022)

# %%
spanish_hits = pd.concat([p2000, p2001,p2002,p2003,p2004,p2005,p2006,\
                         p2007,p2008,p2009,p2010,p2011,p2012,p2013,p2014,p2015,\
                         p2016,p2017,p20182019,p2020,p2021,p2022]).reset_index(drop=True)

# %%
spanish_hits
# Out:
#                artist_name                   track_name  energy  danceability  \
# 0                 Coldplay                       Yellow   0.661         0.429
# 1                   Amaral                  Cómo hablar   0.775         0.606
# 2                   Eminem          The Real Slim Shady   0.661         0.949
# 3           Britney Spears       Oops!...I Did It Again   0.834         0.751
# 4     La Oreja de Van Gogh                     La Playa   0.552         0.589
# ...                    ...                          ...     ...           ...
# 2145           Omar Montes                      Risueña   0.884         0.770
# 2146                 Fuego               Una Vaina Loca   0.588         0.811
# 2147                  Feid  Si Te La Encuentras Por Ahí   0.569         0.736
# 2148    Daviles de Novelda           Flamenco y Bachata   0.871         0.769
# 2149             Bad Bunny            Enséñame a Bailar   0.789         0.810
#
#       loudness  acousticness  speechiness  liveness  valence    tempo  \
# 0       -7.227       0.00239       0.0281    0.2340    0.285  173.372
# 1       -4.752       0.03560       0.0291    0.1110    0.626  117.357
# 2       -4.244       0.03020       0.0572    0.0454    0.760  104.504
# 3       -5.444       0.30000       0.0437    0.3550    0.894   95.053
# 4       -5.707       0.17500       0.0268    0.1060    0.311   88.535
# ...        ...           ...          ...       ...      ...      ...
# 2145    -2.531       0.04890       0.0353    0.0780    0.960  139.977
# 2146    -3.161       0.12800       0.0464    0.0929    0.553  107.022
# 2147    -3.559       0.14400       0.0779    0.1120    0.433  171.973
# 2148    -4.717       0.26600       0.0286    0.1110    0.970  135.032
# 2149    -5.080       0.19100       0.0846    0.4670    0.770  105.009
#
#       duration
# 0       266.77
# 1       241.27
# 2       284.20
# 3       211.16
# 4       247.69
# ...        ...
# 2145    211.89
# 2146    226.19
# 2147    191.51
# 2148    191.33
# 2149    176.00
#
# [2150 rows x 11 columns]

# %%
play = sp.playlist_tracks(playlist_9_dec, fields=None, limit=100,\
                          offset=0, market=None, additional_types=('track', 'episode'))

# %%
links_track = []
for e in (play['items']):
    links_track.append(e['track']['external_urls']['spotify'])

# %%
audio_features = []
for e in links_track:
    audio_features.append(sp.audio_features(e))

# %%
track_song = []

for e in (play['items']):
    track_song.append(e['track']['name'])

# %%
track_song

# %%
artist_name = []

for e in (play['items']):
    artist_name.append(e['track']['album']['artists'][0]['name'])

# %%
audio_features=[e[0] for e in audio_features]

# %%
datos_spotipy = pd.DataFrame(audio_features)

# %%
datos_spotipy.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.358   0.284    7    -8.285     1       0.0285        0.8050
# 1         0.693   0.631    9    -6.105     1       0.0570        0.0827
# 2         0.493   0.613    1    -6.636     1       0.4140        0.0393
# 3         0.431   0.340    0    -9.384     1       0.0311        0.7940
# 4         0.624   0.433    6    -9.572     1       0.0467        0.8370
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000     0.183   0.2760   99.796  audio_features
# 1          0.000087     0.194   0.3620  118.008  audio_features
# 2          0.000000     0.128   0.3730  156.104  audio_features
# 3          0.010800     0.120   0.0529  119.877  audio_features
# 4          0.029400     0.113   0.5890  124.979  audio_features
#
#                        id                                   uri  \
# 0  5Y35SjAfXjjG0sFQ3KOxmm  spotify:track:5Y35SjAfXjjG0sFQ3KOxmm
# 1  2QeUnYtvlfQdfWxzF3b1ud  spotify:track:2QeUnYtvlfQdfWxzF3b1ud
# 2  2UQ2oUbHiB8wWYCE42JX0k  spotify:track:2UQ2oUbHiB8wWYCE42JX0k
# 3  5U1OEoEW4xnalSAToamwZL  spotify:track:5U1OEoEW4xnalSAToamwZL
# 4  4h5x3XHLVYFJaItKuO2rhy  spotify:track:4h5x3XHLVYFJaItKuO2rhy
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/5Y35SjAfXjjG...
# 1  https://api.spotify.com/v1/tracks/2QeUnYtvlfQd...
# 2  https://api.spotify.com/v1/tracks/2UQ2oUbHiB8w...
# 3  https://api.spotify.com/v1/tracks/5U1OEoEW4xna...
# 4  https://api.spotify.com/v1/tracks/4h5x3XHLVYFJ...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/5Y35...       180853
# 1  https://api.spotify.com/v1/audio-analysis/2QeU...       233279
# 2  https://api.spotify.com/v1/audio-analysis/2UQ2...       197692
# 3  https://api.spotify.com/v1/audio-analysis/5U1O...       285051
# 4  https://api.spotify.com/v1/audio-analysis/4h5x...       218587
#
#    time_signature
# 0               3
# 1               4
# 2               4
# 3               4
# 4               4

# %%
datos_spotipy['artist_name'] = artist_name

# %%
datos_spotipy['track_name'] = track_song

# %%
datos_spotipy_mal = datos_spotipy[['type','id','uri','track_href','analysis_url','time_signature','key','mode']]

# %%
datos_spotipy.drop(['type','id','uri','track_href','analysis_url','time_signature','key','mode'],axis=1, inplace=True)

# %%
datos_spotipy.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.358   0.284    -8.285       0.0285        0.8050
# 1         0.693   0.631    -6.105       0.0570        0.0827
# 2         0.493   0.613    -6.636       0.4140        0.0393
# 3         0.431   0.340    -9.384       0.0311        0.7940
# 4         0.624   0.433    -9.572       0.0467        0.8370
#
#    instrumentalness  liveness  valence    tempo  duration_ms  \
# 0          0.000000     0.183   0.2760   99.796       180853
# 1          0.000087     0.194   0.3620  118.008       233279
# 2          0.000000     0.128   0.3730  156.104       197692
# 3          0.010800     0.120   0.0529  119.877       285051
# 4          0.029400     0.113   0.5890  124.979       218587
#
#          artist_name                                         track_name
# 0                SZA                                     Nobody Gets Me
# 1  Caroline Polachek                               Welcome To My Island
# 2             Polo G                                             My All
# 3       Lana Del Rey  Did you know that there's a tunnel under Ocean...
# 4                SZA       Ghost in the Machine (feat. Phoebe Bridgers)

# %%
datos_spotipy=datos_spotipy.iloc[:, [10,11,1,0,2,4,3,6,7,8,9]]

# %%
datos_spotipy.head()
# Out:
#          artist_name                                         track_name  \
# 0                SZA                                     Nobody Gets Me
# 1  Caroline Polachek                               Welcome To My Island
# 2             Polo G                                             My All
# 3       Lana Del Rey  Did you know that there's a tunnel under Ocean...
# 4                SZA       Ghost in the Machine (feat. Phoebe Bridgers)
#
#    energy  danceability  loudness  acousticness  speechiness  liveness  \
# 0   0.284         0.358    -8.285        0.8050       0.0285     0.183
# 1   0.631         0.693    -6.105        0.0827       0.0570     0.194
# 2   0.613         0.493    -6.636        0.0393       0.4140     0.128
# 3   0.340         0.431    -9.384        0.7940       0.0311     0.120
# 4   0.433         0.624    -9.572        0.8370       0.0467     0.113
#
#    valence    tempo  duration_ms
# 0   0.2760   99.796       180853
# 1   0.3620  118.008       233279
# 2   0.3730  156.104       197692
# 3   0.0529  119.877       285051
# 4   0.5890  124.979       218587

# %%
datos_spotipy.rename(columns = {'duration_ms':'duration'}, inplace = True)

# %%
datos_spotipy['duration'] = (datos_spotipy['duration']/1000).round(2)

datos_spotipy.head()
# Out:
#          artist_name                                         track_name  \
# 0                SZA                                     Nobody Gets Me
# 1  Caroline Polachek                               Welcome To My Island
# 2             Polo G                                             My All
# 3       Lana Del Rey  Did you know that there's a tunnel under Ocean...
# 4                SZA       Ghost in the Machine (feat. Phoebe Bridgers)
#
#    energy  danceability  loudness  acousticness  speechiness  liveness  \
# 0   0.284         0.358    -8.285        0.8050       0.0285     0.183
# 1   0.631         0.693    -6.105        0.0827       0.0570     0.194
# 2   0.613         0.493    -6.636        0.0393       0.4140     0.128
# 3   0.340         0.431    -9.384        0.7940       0.0311     0.120
# 4   0.433         0.624    -9.572        0.8370       0.0467     0.113
#
#    valence    tempo  duration
# 0   0.2760   99.796    180.85
# 1   0.3620  118.008    233.28
# 2   0.3730  156.104    197.69
# 3   0.0529  119.877    285.05
# 4   0.5890  124.979    218.59

# %%
datos_spotipy.to_csv('../Proyecto-FInal-Spotify/CSV_full/data_week_9DEC.csv', index=False)
