# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth

# %%
auth_manager = SpotifyClientCredentials('74c040f7ab8049648ec083fdadfc1ddb','a9fa947f1cde460bb37b94060380a6cb')
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
playlist_2_dec = 'https://open.spotify.com/playlist/37i9dQZF1DX4JAvHpjipBk'

# %%
play = sp.playlist_tracks(playlist_2_dec, fields=None, limit=100,\
                          offset=0, market=None, additional_types=('track', 'episode'))

# %%
links_track = []
for e in (play['items']):
    links_track.append(e['track']['external_urls']['spotify'])

# %%
audio_features = []
for e in links_track:
    audio_features.append(sp.audio_features(e))

# %%
track_song = []

for e in (play['items']):
    track_song.append(e['track']['name'])

# %%
artist_name = []

for e in (play['items']):
    artist_name.append(e['track']['album']['artists'][0]['name'])

# %%
audio_features=[e[0] for e in audio_features]

# %%
datos_spotipy = pd.DataFrame(audio_features)

# %%
datos_spotipy.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.715   0.620    1    -6.005     0       0.0484        0.4170
# 1         0.325   0.590    4    -3.943     1       0.0495        0.0686
# 2         0.887   0.234    9   -14.520     1       0.1780        0.1110
# 3         0.656   0.838    5    -8.407     1       0.0410        0.2500
# 4         0.738   0.659    1    -2.398     1       0.1700        0.0411
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.00000    0.0822    0.172   97.950  audio_features
# 1           0.00000    0.1040    0.278  180.449  audio_features
# 2           0.67000    0.1300    0.197  140.020  audio_features
# 3           0.00281    0.2070    0.740  132.981  audio_features
# 4           0.00000    0.0681    0.488  148.007  audio_features
#
#                        id                                   uri  \
# 0  2dHHgzDwk4BJdRwy9uXhTO  spotify:track:2dHHgzDwk4BJdRwy9uXhTO
# 1  4JBiO7wRnE6ueszEUpo347  spotify:track:4JBiO7wRnE6ueszEUpo347
# 2  2mnXxnrX5vCGolNkaFvVeM  spotify:track:2mnXxnrX5vCGolNkaFvVeM
# 3  3NanY0K4okhIQzL33U5Ad8  spotify:track:3NanY0K4okhIQzL33U5Ad8
# 4  31UJ8vd4JQc1JEa7TgcDSz  spotify:track:31UJ8vd4JQc1JEa7TgcDSz
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2dHHgzDwk4BJ...
# 1  https://api.spotify.com/v1/tracks/4JBiO7wRnE6u...
# 2  https://api.spotify.com/v1/tracks/2mnXxnrX5vCG...
# 3  https://api.spotify.com/v1/tracks/3NanY0K4okhI...
# 4  https://api.spotify.com/v1/tracks/31UJ8vd4JQc1...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2dHH...       221520
# 1  https://api.spotify.com/v1/audio-analysis/4JBi...       235752
# 2  https://api.spotify.com/v1/audio-analysis/2mnX...       196800
# 3  https://api.spotify.com/v1/audio-analysis/3Nan...       131253
# 4  https://api.spotify.com/v1/audio-analysis/31UJ...       144730
#
#    time_signature
# 0               4
# 1               3
# 2               4
# 3               4
# 4               4

# %%
datos_spotipy['artist_name'] = artist_name

# %%
datos_spotipy['track_name'] = track_song

# %%
datos_spotipy_mal = datos_spotipy[['type','id','uri','track_href','analysis_url','time_signature','key','mode']]

# %%
datos_spotipy.drop(['type','id','uri','track_href','analysis_url','time_signature','key','mode'],axis=1, inplace=True)

# %%
datos_spotipy.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.715   0.620    -6.005       0.0484        0.4170
# 1         0.325   0.590    -3.943       0.0495        0.0686
# 2         0.887   0.234   -14.520       0.1780        0.1110
# 3         0.656   0.838    -8.407       0.0410        0.2500
# 4         0.738   0.659    -2.398       0.1700        0.0411
#
#    instrumentalness  liveness  valence    tempo  duration_ms     artist_name  \
# 0           0.00000    0.0822    0.172   97.950       221520    Metro Boomin
# 1           0.00000    0.1040    0.278  180.449       235752   Lewis Capaldi
# 2           0.67000    0.1300    0.197  140.020       196800        Arcángel
# 3           0.00281    0.2070    0.740  132.981       131253  PinkPantheress
# 4           0.00000    0.0681    0.488  148.007       144730      A$AP Rocky
#
#                                track_name
# 0  Creepin' (with The Weeknd & 21 Savage)
# 1                               Pointless
# 2                                La Jumpa
# 3                            Boy's a liar
# 4                             Shittin' Me

# %%
datos_spotipy=datos_spotipy.iloc[:, [10,11,1,0,2,4,3,6,7,8,9]]

# %%
datos_spotipy.head()
# Out:
#       artist_name                              track_name  energy  \
# 0    Metro Boomin  Creepin' (with The Weeknd & 21 Savage)   0.620
# 1   Lewis Capaldi                               Pointless   0.590
# 2        Arcángel                                La Jumpa   0.234
# 3  PinkPantheress                            Boy's a liar   0.838
# 4      A$AP Rocky                             Shittin' Me   0.659
#
#    danceability  loudness  acousticness  speechiness  liveness  valence  \
# 0         0.715    -6.005        0.4170       0.0484    0.0822    0.172
# 1         0.325    -3.943        0.0686       0.0495    0.1040    0.278
# 2         0.887   -14.520        0.1110       0.1780    0.1300    0.197
# 3         0.656    -8.407        0.2500       0.0410    0.2070    0.740
# 4         0.738    -2.398        0.0411       0.1700    0.0681    0.488
#
#      tempo  duration_ms
# 0   97.950       221520
# 1  180.449       235752
# 2  140.020       196800
# 3  132.981       131253
# 4  148.007       144730

# %%
datos_spotipy.rename(columns = {'duration_ms':'duration'}, inplace = True)
# Out:
# /var/folders/0p/q9p3n_m96v7fgw9v0l4dvkyr0000gn/T/ipykernel_41258/3791978515.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_spotipy.rename(columns = {'duration_ms':'duration'}, inplace = True)

# %%
datos_spotipy['duration'] = (datos_spotipy['duration']/1000).round(2)

datos_spotipy.head()
# Out:
# /var/folders/0p/q9p3n_m96v7fgw9v0l4dvkyr0000gn/T/ipykernel_41258/3354237344.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   datos_spotipy['duration'] = (datos_spotipy['duration']/1000).round(2)
#       artist_name                              track_name  energy  \
# 0    Metro Boomin  Creepin' (with The Weeknd & 21 Savage)   0.620
# 1   Lewis Capaldi                               Pointless   0.590
# 2        Arcángel                                La Jumpa   0.234
# 3  PinkPantheress                            Boy's a liar   0.838
# 4      A$AP Rocky                             Shittin' Me   0.659
#
#    danceability  loudness  acousticness  speechiness  liveness  valence  \
# 0         0.715    -6.005        0.4170       0.0484    0.0822    0.172
# 1         0.325    -3.943        0.0686       0.0495    0.1040    0.278
# 2         0.887   -14.520        0.1110       0.1780    0.1300    0.197
# 3         0.656    -8.407        0.2500       0.0410    0.2070    0.740
# 4         0.738    -2.398        0.0411       0.1700    0.0681    0.488
#
#      tempo  duration
# 0   97.950    221.52
# 1  180.449    235.75
# 2  140.020    196.80
# 3  132.981    131.25
# 4  148.007    144.73

# %%
datos_spotipy.to_csv('../Proyecto-FInal-Spotify/CSV_full/data_week_2DEC.csv', index=False)
