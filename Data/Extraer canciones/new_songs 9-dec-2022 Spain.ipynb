# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from spotipy.oauth2 import SpotifyOAuth

# %%
auth_manager = SpotifyClientCredentials('74c040f7ab8049648ec083fdadfc1ddb','a9fa947f1cde460bb37b94060380a6cb')
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
playlist_9_dec = 'https://open.spotify.com/playlist/37i9dQZF1DX6PYajiT4pAf'

# %%
play = sp.playlist_tracks(playlist_9_dec, fields=None, limit=100,\
                          offset=0, market=None, additional_types=('track', 'episode'))

# %%
links_track = []
for e in (play['items']):
    links_track.append(e['track']['external_urls']['spotify'])

# %%
audio_features = []
for e in links_track:
    audio_features.append(sp.audio_features(e))

# %%
track_song = []

for e in (play['items']):
    track_song.append(e['track']['name'])

# %%
track_song
# Out:
# ['LLYLM',
#  'PANTIES Y BRASIERES',
#  'Plaza en el cielo',
#  'Te Miro A La Cara',
#  'Cuzi Cuza',
#  'El Principio de algo',
#  'cosquillas',
#  'Un Verano Sin Ti',
#  'PEM',
#  'I’m Not Here To Make Friends (feat. Calvin Harris & Jessie Reyez)',
#  'Vuelve',
#  'Te Comía',
#  'Tranquilo',
#  'Por el Resto de Tu Vida',
#  'Te Amo',
#  'Baby Father 2.0 (feat. Myke Towers, Arcángel, Ñengo Flow and Yeruza)',
#  'Ahora No Lloro',
#  'Show U',
#  "T'as peur",
#  'Bendita',
#  'POR NO DECIR TU NOMBRE',
#  'Ya No Te Escribo',
#  'Tanta Lucha',
#  'EL SECRETO - Mambata',
#  'London Blue',
#  'Tras De Ti',
#  'Sirocco',
#  'La Joaqui | Omar Algo Anda Mal #5',
#  'Hola, Qué Tal',
#  'Los Besos',
#  'RUMBACUMBIA',
#  'Dime',
#  'Sin Conexión',
#  'EXTASI',
#  'Love Again',
#  'Ghost',
#  'TRUSTFALL',
#  'Butterflies (feat. AURORA)',
#  'Los Perros',
#  'Bailando mal',
#  'Nubes',
#  'A Banda',
#  'París',
#  'Chocamos',
#  'inocentes',
#  'La Función',
#  'Seda',
#  'Citant Mercè Rodoreda',
#  'Luna Llena',
#  '¿Qué Tengo Que Hacer?',
#  'La Promesa',
#  'AT!KE (A ti qué te importa)',
#  'El Lao De La Pena',
#  'Ya Puede Caerse el Cielo',
#  'El Diablo gritó sí',
#  'isaac',
#  'Ártica',
#  'Mariana',
#  'Rockstar',
#  'Para qué']

# %%
artist_name = []

for e in (play['items']):
    artist_name.append(e['track']['album']['artists'][0]['name'])

# %%
audio_features=[e[0] for e in audio_features]

# %%
datos_spotipy = pd.DataFrame(audio_features)

# %%
datos_spotipy.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.555   0.634    6    -5.522     0       0.2730        0.1290
# 1         0.758   0.888    1    -2.851     1       0.0706        0.3400
# 2         0.435   0.390    7    -6.818     1       0.0449        0.0665
# 3         0.575   0.782    1    -5.158     1       0.0992        0.2160
# 4         0.799   0.652   10    -8.405     0       0.0802        0.5940
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000002    0.1880    0.555  170.228  audio_features
# 1          0.001390    0.1440    0.408  107.039  audio_features
# 2          0.000111    0.2450    0.333  123.032  audio_features
# 3          0.000000    0.2720    0.869   85.126  audio_features
# 4          0.367000    0.0991    0.609  129.995  audio_features
#
#                        id                                   uri  \
# 0  2SiAcexM2p1yX6joESbehd  spotify:track:2SiAcexM2p1yX6joESbehd
# 1  0fADaWdT3obxk7zvHS18VY  spotify:track:0fADaWdT3obxk7zvHS18VY
# 2  330mS1U6KJ9Gie5PL4gkAo  spotify:track:330mS1U6KJ9Gie5PL4gkAo
# 3  7hlPoVZ1uz7FiQagPTVbQG  spotify:track:7hlPoVZ1uz7FiQagPTVbQG
# 4  3ZEcE3DPL1DdDFqyvbmkBZ  spotify:track:3ZEcE3DPL1DdDFqyvbmkBZ
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2SiAcexM2p1y...
# 1  https://api.spotify.com/v1/tracks/0fADaWdT3obx...
# 2  https://api.spotify.com/v1/tracks/330mS1U6KJ9G...
# 3  https://api.spotify.com/v1/tracks/7hlPoVZ1uz7F...
# 4  https://api.spotify.com/v1/tracks/3ZEcE3DPL1Dd...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2SiA...       174045
# 1  https://api.spotify.com/v1/audio-analysis/0fAD...       197383
# 2  https://api.spotify.com/v1/audio-analysis/330m...       206616
# 3  https://api.spotify.com/v1/audio-analysis/7hlP...       142900
# 4  https://api.spotify.com/v1/audio-analysis/3ZEc...       167861
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
datos_spotipy['artist_name'] = artist_name

# %%
datos_spotipy['track_name'] = track_song

# %%
datos_spotipy['links'] = links_track

# %%
datos_spotipy_mal = datos_spotipy[['type','id','uri','track_href','analysis_url','time_signature','key','mode']]

# %%
datos_spotipy.drop(['type','id','uri','track_href','analysis_url','time_signature','key','mode'],axis=1, inplace=True)

# %%
datos_spotipy.head()
# Out:
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.555   0.634    -5.522       0.2730        0.1290
# 1         0.758   0.888    -2.851       0.0706        0.3400
# 2         0.435   0.390    -6.818       0.0449        0.0665
# 3         0.575   0.782    -5.158       0.0992        0.2160
# 4         0.799   0.652    -8.405       0.0802        0.5940
#
#    instrumentalness  liveness  valence    tempo  duration_ms  \
# 0          0.000002    0.1880    0.555  170.228       174045
# 1          0.001390    0.1440    0.408  107.039       197383
# 2          0.000111    0.2450    0.333  123.032       206616
# 3          0.000000    0.2720    0.869   85.126       142900
# 4          0.367000    0.0991    0.609  129.995       167861
#
#           artist_name           track_name  \
# 0             ROSALÍA                LLYLM
# 1      Rauw Alejandro  PANTIES Y BRASIERES
# 2          Marc Seguí    Plaza en el cielo
# 3  Daviles de Novelda    Te Miro A La Cara
# 4               Morad            Cuzi Cuza
#
#                                                links
# 0  https://open.spotify.com/track/2SiAcexM2p1yX6j...
# 1  https://open.spotify.com/track/0fADaWdT3obxk7z...
# 2  https://open.spotify.com/track/330mS1U6KJ9Gie5...
# 3  https://open.spotify.com/track/7hlPoVZ1uz7FiQa...
# 4  https://open.spotify.com/track/3ZEcE3DPL1DdDFq...

# %%
datos_spotipy=datos_spotipy.iloc[:, [10,11,1,0,2,4,3,6,7,8,9,12]]

# %%
datos_spotipy.head()
# Out:
#           artist_name           track_name  energy  danceability  loudness  \
# 0             ROSALÍA                LLYLM   0.634         0.555    -5.522
# 1      Rauw Alejandro  PANTIES Y BRASIERES   0.888         0.758    -2.851
# 2          Marc Seguí    Plaza en el cielo   0.390         0.435    -6.818
# 3  Daviles de Novelda    Te Miro A La Cara   0.782         0.575    -5.158
# 4               Morad            Cuzi Cuza   0.652         0.799    -8.405
#
#    acousticness  speechiness  liveness  valence    tempo  duration_ms  \
# 0        0.1290       0.2730    0.1880    0.555  170.228       174045
# 1        0.3400       0.0706    0.1440    0.408  107.039       197383
# 2        0.0665       0.0449    0.2450    0.333  123.032       206616
# 3        0.2160       0.0992    0.2720    0.869   85.126       142900
# 4        0.5940       0.0802    0.0991    0.609  129.995       167861
#
#                                                links
# 0  https://open.spotify.com/track/2SiAcexM2p1yX6j...
# 1  https://open.spotify.com/track/0fADaWdT3obxk7z...
# 2  https://open.spotify.com/track/330mS1U6KJ9Gie5...
# 3  https://open.spotify.com/track/7hlPoVZ1uz7FiQa...
# 4  https://open.spotify.com/track/3ZEcE3DPL1DdDFq...

# %%
datos_spotipy.rename(columns = {'duration_ms':'duration'}, inplace = True)

# %%
datos_spotipy['duration'] = (datos_spotipy['duration']/1000).round(2)

datos_spotipy.head()
# Out:
#           artist_name           track_name  energy  danceability  loudness  \
# 0             ROSALÍA                LLYLM   0.634         0.555    -5.522
# 1      Rauw Alejandro  PANTIES Y BRASIERES   0.888         0.758    -2.851
# 2          Marc Seguí    Plaza en el cielo   0.390         0.435    -6.818
# 3  Daviles de Novelda    Te Miro A La Cara   0.782         0.575    -5.158
# 4               Morad            Cuzi Cuza   0.652         0.799    -8.405
#
#    acousticness  speechiness  liveness  valence    tempo  duration  \
# 0        0.1290       0.2730    0.1880    0.555  170.228    174.04
# 1        0.3400       0.0706    0.1440    0.408  107.039    197.38
# 2        0.0665       0.0449    0.2450    0.333  123.032    206.62
# 3        0.2160       0.0992    0.2720    0.869   85.126    142.90
# 4        0.5940       0.0802    0.0991    0.609  129.995    167.86
#
#                                                links
# 0  https://open.spotify.com/track/2SiAcexM2p1yX6j...
# 1  https://open.spotify.com/track/0fADaWdT3obxk7z...
# 2  https://open.spotify.com/track/330mS1U6KJ9Gie5...
# 3  https://open.spotify.com/track/7hlPoVZ1uz7FiQa...
# 4  https://open.spotify.com/track/3ZEcE3DPL1DdDFq...

# %%
datos_spotipy.to_csv('../CSV_full/data_hackshow_spain.csv', index=False)
