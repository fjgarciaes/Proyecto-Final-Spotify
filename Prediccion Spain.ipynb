# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import pylab as plt
import seaborn as sns
import re
import warnings
warnings.filterwarnings('ignore') 
#para que salga el grafico
#pd.set_option('display.max_rows', None)
from statistics import mean
import pylab as plt
from sklearn.preprocessing import StandardScaler

from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import SVC
from sklearn.calibration import CalibratedClassifierCV
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.semi_supervised import LabelPropagation
from sklearn.semi_supervised import LabelSpreading
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.linear_model import RidgeClassifierCV
from sklearn.linear_model import RidgeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import ExtraTreeClassifier 
from sklearn.model_selection import train_test_split as tts   
from sklearn.metrics import accuracy_score as acc
from sklearn.metrics import f1_score as f1  
from sklearn.tree import DecisionTreeRegressor as DTR
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %% [markdown]
# # PROYECTO FINAL EMPIEZA AQUI

# %% [markdown]
# # Voy a probar cosas nuevas que no tienen que ver con la ETL que ya hice a ver que puedo ir metiendo

# %% [markdown]
# # SQL

# %%
#with open('../Proyecto-FInal-Spotify/token.txt', 'r') as file:
    #contraseña=file.read()

# %%
#from sqlalchemy import create_engine

# %%
#str_conn=f'mysql+pymysql://root:{contraseña}@localhost:3306/proyecto_final'

#cursor=create_engine(str_conn)

# %%
#hit_or_not.to_sql(name='hit_or_not', con=cursor, if_exists='replace',index=False)

# %% [markdown]
# # COLINEALIDAD

# %% [markdown]
# # Feature importances

# %%
#X=hit_or_not_normal.drop(columns=['top_hit'])
#y=hit_or_not_normal.top_hit

# %%
#machine_learning()

# %%
#HGBT.fit(X_train, y_train)

# %%
#y_pred = HGBT.predict(X_test)

# %%
#y_pred

# %%
#indices = list(X_test.index)

# %%
#probab = hit_or_not_normal.iloc[indices].reset_index(drop=True)

# %%
#pred = pd.Series(y_pred)

# %%
#pred_test=pd.DataFrame(y_test).reset_index(drop=True)

# %%
#probab['prediccion'] = pred.round(decimals = 0)

# %%
probab['fallo'] = probab['top_hit'] - probab['prediccion']
probab[probab['fallo']!=0]

# %% [markdown]
# # El modelo funciona ahora voy a predecir los posibles exitos de las canciones que salieron la semana pasada de la playlist new music Friday.

# %%
datos_spotipy_week_1 = pd.read_csv('../Proyecto-FInal-Spotify/CSV_full/data_week_2DEC.csv')

# %%
datos_spotipy_week_1.drop_duplicates().shape==datos_spotipy_week_1.shape    # NO hay duplicados
# Out:
# True

# %%
datos_spotipy_week_1.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   artist_name   100 non-null    object
#  1   track_name    100 non-null    object
#  2   energy        100 non-null    float64
#  3   danceability  100 non-null    float64
#  4   loudness      100 non-null    float64
#  5   acousticness  100 non-null    float64
#  6   speechiness   100 non-null    float64
#  7   liveness      100 non-null    float64
#  8   valence       100 non-null    float64
#  9   tempo         100 non-null    float64
#  10  duration      100 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 20.9 KB

# %%
# Out:
#       artist_name                              track_name  energy  \
# 0    Metro Boomin  Creepin' (with The Weeknd & 21 Savage)   0.620
# 1   Lewis Capaldi                               Pointless   0.590
# 2        Arcángel                                La Jumpa   0.234
# 3  PinkPantheress                            Boy's a liar   0.838
# 4      A$AP Rocky                             Shittin' Me   0.659
#
#    danceability  loudness  acousticness  speechiness  liveness  valence  \
# 0         0.715    -6.005        0.4170       0.0484    0.0822    0.172
# 1         0.325    -3.943        0.0686       0.0495    0.1040    0.278
# 2         0.887   -14.520        0.1110       0.1780    0.1300    0.197
# 3         0.656    -8.407        0.2500       0.0410    0.2070    0.740
# 4         0.738    -2.398        0.0411       0.1700    0.0681    0.488
#
#      tempo  duration
# 0   97.950    221.52
# 1  180.449    235.75
# 2  140.020    196.80
# 3  132.981    131.25
# 4  148.007    144.73

# %%
datos_spotipy_week_1norm = datos_spotipy_week_1.copy()

# %%
datos_spotipy_week_1norm['artist_name']=LabelEncoder().fit_transform(datos_spotipy_week_1norm['artist_name'])

# %%
datos_spotipy_week_1norm[['energy','danceability','loudness','acousticness','speechiness','liveness',\
                  'valence','tempo','duration','artist_name']] = scaler.fit_transform(datos_spotipy_week_1norm[['energy',\
                    'danceability','loudness','acousticness','speechiness','liveness',\
                  'valence','tempo','duration','artist_name']])

# %%
datos_spotipy_week_1norm.head()

# %%
datos_spotipy_week_1norm.drop(['track_name'],axis=1,inplace=True)

# %%
y_pred = HGBT.predict(datos_spotipy_week_1norm)

# %%
datos_spotipy_week_1norm.shape

# %%
datos_spotipy_week_1norm.head()

# %%
pred1 = pd.Series(y_pred)

# %%
datos_spotipy_week_1['prediccion'] = pred1.round(decimals = 0)

# %%
datos_spotipy_week_1.prediccion.value_counts()

# %%
hit_or_not['artist_name'].value_counts()

# %%
datos_spotipy_week_1

# %%
datos_spotipy_week_2 = pd.read_csv('../Proyecto-FInal-Spotify/CSV_full/data_week_9DEC.csv')

# %%
datos_spotipy_week_2.drop_duplicates().shape==datos_spotipy_week_2.shape    # NO hay duplicados

# %%
datos_spotipy_week_2.info(memory_usage='deep')

# %%
datos_spotipy_week_2norm = datos_spotipy_week_2.copy()

# %%
datos_spotipy_week_2norm['artist_name']=LabelEncoder().fit_transform(datos_spotipy_week_2norm['artist_name'])

# %%
datos_spotipy_week_2norm[['energy','danceability','loudness','acousticness','speechiness','liveness',\
                  'valence','tempo','duration','artist_name']] = scaler.fit_transform(datos_spotipy_week_2norm[['energy',\
                    'danceability','loudness','acousticness','speechiness','liveness',\
                  'valence','tempo','duration','artist_name']])

# %%
datos_spotipy_week_2norm.drop(['track_name'],axis=1,inplace=True)

# %%
y_pred_week2 = HGBT.predict(datos_spotipy_week_2norm)

# %%
pred_week2= pd.Series(y_pred_week2)

# %%
datos_spotipy_week_2['prediccion'] = pred_week2.round(decimals = 0)

# %%
datos_spotipy_week_2.prediccion.value_counts()

# %%
datos_spotipy_week_2

# %% [markdown]
# # PARA ESPAÑA

# %%
spanish_hits = pd.read_csv('../Proyecto-FInal-Spotify/CSV_primeros/spanish_hits.csv')

spanish_hits.head()
# Out:
#             artist_name              track_name  energy  danceability  \
# 0              Coldplay                  Yellow   0.661         0.429
# 1                Amaral             Cómo hablar   0.775         0.606
# 2                Eminem     The Real Slim Shady   0.661         0.949
# 3        Britney Spears  Oops!...I Did It Again   0.834         0.751
# 4  La Oreja de Van Gogh                La Playa   0.552         0.589
#
#    loudness  acousticness  speechiness  liveness  valence    tempo  duration
# 0    -7.227       0.00239       0.0281    0.2340    0.285  173.372    266.77
# 1    -4.752       0.03560       0.0291    0.1110    0.626  117.357    241.27
# 2    -4.244       0.03020       0.0572    0.0454    0.760  104.504    284.20
# 3    -5.444       0.30000       0.0437    0.3550    0.894   95.053    211.16
# 4    -5.707       0.17500       0.0268    0.1060    0.311   88.535    247.69

# %%
spanish_hits['top_hit']=[1 for i in range(len(spanish_hits))]

# %%
spanish_hits.shape
# Out:
# (2050, 12)

# %%
unpopular_spain = pd.read_csv('../Spoti/unpopular_songs.csv')

unpopular_spain.shape
# Out:
# (10877, 17)

# %%
unpopular_spain = unpopular_spain.sample(n=2050)

# %%
unpopular_spain.drop(['explicit','mode','popularity','key','track_id','instrumentalness'],axis=1,inplace=True)

# %%
unpopular_spain=unpopular_spain.iloc[:, [10,9,1,0,2,4,3,5,6,7,8]]

# %%
unpopular_spain.rename(columns = {'track_artist':'artist_name', 'track_name':'track_name',
                            'duration_ms':'duration'}, inplace = True)

# %%
unpopular_spain
# Out:
#                                  artist_name  \
# 3377                                    Saca
# 5597                          Black Da Runna
# 5626                                    Mase
# 8111                    The Modest Pleasures
# 9159                           Yoga Playlist
# ...                                      ...
# 4315  J.J. Caillier and the Zydeco Knockouts
# 8580                            Cooper Glass
# 3174        Restaurant Jazz Music Collection
# 2394                         Piano Dreamland
# 6013                               Tyne Daly
#
#                             track_name  energy  danceability  loudness  \
# 3377                               IDK  0.6090         0.429    -9.450
# 5597                     Thug Brothers  0.6720         0.740    -5.279
# 5626  Love U So [feat. Billy Lawrence]  0.7120         0.796    -7.910
# 8111               Where Herbert Lives  0.5220         0.160   -15.287
# 9159                   Unknown Forward  0.2220         0.187   -18.111
# ...                                ...     ...           ...       ...
# 4315      I Can Give You What You Want  0.5530         0.694   -13.135
# 8580                            Evolve  0.4210         0.850    -8.559
# 3174                  Jazzy Collection  0.3740         0.646   -16.780
# 2394                        Wildflower  0.0925         0.644   -20.945
# 6013   A Mother Doesn't Matter Anymore  0.3800         0.573   -10.460
#
#       acousticness  speechiness  liveness  valence    tempo  duration
# 3377        0.0767       0.3610     0.243    0.313   71.980    230034
# 5597        0.0926       0.2620     0.326    0.595  140.020    194743
# 5626        0.0758       0.2320     0.627    0.582  108.551    192187
# 8111        0.0365       0.0592     0.462    0.039   59.855     81734
# 9159        0.9610       0.0598     0.161    0.075  155.710     30892
# ...            ...          ...       ...      ...      ...       ...
# 4315        0.0325       0.0392     0.110    0.746  150.246    335520
# 8580        0.0948       0.2400     0.113    0.266  139.979    194142
# 3174        0.0263       0.0388     0.115    0.831  119.986    201224
# 2394        0.9830       0.0344     0.111    0.296  104.636    147114
# 6013        0.5930       0.1460     0.138    0.310  123.376    222667
#
# [2050 rows x 11 columns]

# %%
unpopular_spain['top_hit']=[0 for i in range(len(unpopular_spain))]

# %%
unpopular_spain['duration'] = (unpopular_spain['duration']/1000).round(2)

unpopular_spain.head()
# Out:
#                artist_name                        track_name  energy  \
# 3377                  Saca                               IDK   0.609
# 5597        Black Da Runna                     Thug Brothers   0.672
# 5626                  Mase  Love U So [feat. Billy Lawrence]   0.712
# 8111  The Modest Pleasures               Where Herbert Lives   0.522
# 9159         Yoga Playlist                   Unknown Forward   0.222
#
#       danceability  loudness  acousticness  speechiness  liveness  valence  \
# 3377         0.429    -9.450        0.0767       0.3610     0.243    0.313
# 5597         0.740    -5.279        0.0926       0.2620     0.326    0.595
# 5626         0.796    -7.910        0.0758       0.2320     0.627    0.582
# 8111         0.160   -15.287        0.0365       0.0592     0.462    0.039
# 9159         0.187   -18.111        0.9610       0.0598     0.161    0.075
#
#         tempo  duration  top_hit
# 3377   71.980    230.03        0
# 5597  140.020    194.74        0
# 5626  108.551    192.19        0
# 8111   59.855     81.73        0
# 9159  155.710     30.89        0

# %%
spain_hit_or_not = pd.concat([spanish_hits,unpopular_spain]).reset_index(drop=True)

# %%
spain_hit_or_not
# Out:
#                                  artist_name                       track_name  \
# 0                                   Coldplay                           Yellow
# 1                                     Amaral                      Cómo hablar
# 2                                     Eminem              The Real Slim Shady
# 3                             Britney Spears           Oops!...I Did It Again
# 4                       La Oreja de Van Gogh                         La Playa
# ...                                      ...                              ...
# 4095  J.J. Caillier and the Zydeco Knockouts     I Can Give You What You Want
# 4096                            Cooper Glass                           Evolve
# 4097        Restaurant Jazz Music Collection                 Jazzy Collection
# 4098                         Piano Dreamland                       Wildflower
# 4099                               Tyne Daly  A Mother Doesn't Matter Anymore
#
#       energy  danceability  loudness  acousticness  speechiness  liveness  \
# 0     0.6610         0.429    -7.227       0.00239       0.0281    0.2340
# 1     0.7750         0.606    -4.752       0.03560       0.0291    0.1110
# 2     0.6610         0.949    -4.244       0.03020       0.0572    0.0454
# 3     0.8340         0.751    -5.444       0.30000       0.0437    0.3550
# 4     0.5520         0.589    -5.707       0.17500       0.0268    0.1060
# ...      ...           ...       ...           ...          ...       ...
# 4095  0.5530         0.694   -13.135       0.03250       0.0392    0.1100
# 4096  0.4210         0.850    -8.559       0.09480       0.2400    0.1130
# 4097  0.3740         0.646   -16.780       0.02630       0.0388    0.1150
# 4098  0.0925         0.644   -20.945       0.98300       0.0344    0.1110
# 4099  0.3800         0.573   -10.460       0.59300       0.1460    0.1380
#
#       valence    tempo  duration  top_hit
# 0       0.285  173.372    266.77        1
# 1       0.626  117.357    241.27        1
# 2       0.760  104.504    284.20        1
# 3       0.894   95.053    211.16        1
# 4       0.311   88.535    247.69        1
# ...       ...      ...       ...      ...
# 4095    0.746  150.246    335.52        0
# 4096    0.266  139.979    194.14        0
# 4097    0.831  119.986    201.22        0
# 4098    0.296  104.636    147.11        0
# 4099    0.310  123.376    222.67        0
#
# [4100 rows x 12 columns]

# %%
spain_hit_or_not.drop_duplicates().shape==spain_hit_or_not.shape
# Out:
# True

# %%
spain_hit_or_not=spain_hit_or_not.drop_duplicates()

# %%
spain_hit_or_not.drop_duplicates().shape==spain_hit_or_not.shape
# Out:
# True

# %%
spain_hit_or_not_norm = spain_hit_or_not.copy()

# %%
spain_hit_or_not_names = spain_hit_or_not.copy()

# %%
spain_hit_or_not_norm.drop(['track_name'],axis=1,inplace=True)

# %%
spain_hit_or_not_norm['artist_name'].value_counts()
# Out:
# Bad Bunny            24
# Melendi              24
# David Bisbal         20
# Various Artists      18
# Amaral               18
#                      ..
# Zacarias Ferreira     1
# Baby Jay              1
# Sons of Vengeance     1
# Marisela              1
# Tyne Daly             1
# Name: artist_name, Length: 1797, dtype: int64

# %%
spanish_hits['artist_name'].value_counts()
# Out:
# Bad Bunny             24
# Melendi               24
# Various Artists       18
# David Bisbal          18
# One Direction         17
#                       ..
# Alex Gaudino           1
# Leona Lewis            1
# Ne-Yo                  1
# Radiohead              1
# Daviles de Novelda     1
# Name: artist_name, Length: 883, dtype: int64

# %%
spain_hit_or_not_norm['artist_name']=LabelEncoder().fit_transform(spain_hit_or_not_norm['artist_name'])

# %%
scaler=StandardScaler()

# %%
spain_hit_or_not_norm[['energy','danceability','loudness','acousticness','speechiness','liveness',\
                  'valence','tempo','duration',
                    'artist_name']] = scaler.fit_transform(spain_hit_or_not_norm[['energy',\
                    'danceability','loudness','acousticness','speechiness','liveness',\
                  'valence','tempo','duration','artist_name']])

# %%
spain_hit_or_not_norm
# Out:
#       artist_name    energy  danceability  loudness  acousticness  \
# 0       -1.060670  0.100089     -1.012502  0.228223     -0.941110
# 1       -1.564364  0.588093     -0.008383  0.658461     -0.830614
# 2       -0.699494  0.100089      1.937453  0.746769     -0.848581
# 3       -1.279328  0.840657      0.814201  0.538169      0.049097
# 4        0.063856 -0.366512     -0.104823  0.492450     -0.366803
# ...           ...       ...           ...       ...           ...
# 4095    -0.293415 -0.362231      0.490841 -0.798785     -0.840928
# 4096    -1.043099 -0.927289      1.375827 -0.003323     -0.633644
# 4097     0.958010 -1.128483      0.218537 -1.432408     -0.861557
# 4098     0.813540 -2.333511      0.207191 -2.156425      2.321572
# 4099     1.559319 -1.102799     -0.195591 -0.333780      1.023965
#
#       speechiness  liveness   valence     tempo  duration  top_hit
# 0       -0.612745  0.184911 -0.919482  1.821660  0.562513        1
# 1       -0.605018 -0.516881  0.384199 -0.094499  0.263682        1
# 2       -0.387888 -0.891169  0.896496 -0.534174  0.766774        1
# 3       -0.492203  0.875291  1.408793 -0.857473 -0.089174        1
# 4       -0.622790 -0.545409 -0.820081 -1.080441  0.338917        1
# ...           ...       ...       ...       ...       ...      ...
# 4095    -0.526975 -0.522586  0.842972  1.030567  1.368188        0
# 4096     1.024614 -0.505469 -0.992121  0.679354 -0.288630        0
# 4097    -0.530066 -0.494058  1.167937 -0.004566 -0.205660        0
# 4098    -0.564065 -0.516881 -0.877428 -0.529658 -0.839770        0
# 4099     0.298272 -0.362829 -0.823904  0.111399  0.045710        0
#
# [4100 rows x 11 columns]

# %%
X=spain_hit_or_not_norm.drop(columns=['top_hit'])
y=spain_hit_or_not_norm.top_hit

dtr=DTR().fit(X, y)

dict(zip(X.columns, dtr.feature_importances_))

sum(dtr.feature_importances_)

X_norm=StandardScaler().fit_transform(X)
dtr=DTR().fit(X_norm, y)

dict(zip(X.columns, dtr.feature_importances_))

rfr=RFR(n_estimators=2000).fit(X_norm, y)

feat_imp = dict(zip(X.columns, rfr.feature_importances_))

# %%
feat_imp
# Out:
# {'artist_name': 0.06213194541506019,
#  'energy': 0.051708977888655944,
#  'danceability': 0.06362640584256736,
#  'loudness': 0.3730961839535413,
#  'acousticness': 0.0756014690417752,
#  'speechiness': 0.08929747423607282,
#  'liveness': 0.05997758109638487,
#  'valence': 0.059893842341810034,
#  'tempo': 0.05293094890378429,
#  'duration': 0.11173517128034784}

# %%
X_train, X_test, y_train, y_test = tts(X, y, train_size=0.8, test_size=0.2, random_state=42)

# %%
linearsvc = LinearSVC()
sgdc = SGDClassifier()
mlpc= MLPClassifier()
percept = Perceptron()
LogReg = LogisticRegression()
LogistReg = LogisticRegressionCV()
svc = SVC()
CCCV = CalibratedClassifierCV()
PAC = PassiveAggressiveClassifier()
LP = LabelPropagation()
LS = LabelSpreading()
rfc = RandomForestClassifier()
GBC = GradientBoostingClassifier()
QDA = QuadraticDiscriminantAnalysis()
HGBT = HistGradientBoostingClassifier()
ridgeCV = RidgeClassifierCV()
ridge = RidgeClassifier()
ABC= AdaBoostClassifier()
ETC = ExtraTreesClassifier()
KNC= KNeighborsClassifier()
BC = BaggingClassifier()
berno = BernoulliNB()
LDA = LinearDiscriminantAnalysis()
gauss =GaussianNB()
nusvc= NuSVC()
DTC = DecisionTreeClassifier()
NC = NearestCentroid()
ETC = ExtraTreeClassifier()

# %%
def machine_learning():
    
    modelos = { 'linearsvc':LinearSVC(), 'sgdc': SGDClassifier(),
                'mlpc': MLPClassifier(),
                'percept':Perceptron(),
                'LogReg':LogisticRegression(),
                'LogistReg': LogisticRegressionCV(),
                'svc':SVC(),
                'CCCV' :CalibratedClassifierCV(),
                'PAC' : PassiveAggressiveClassifier(),
                'LP' : LabelPropagation(),
                'LS' : LabelSpreading(),
                'rfc' : RandomForestClassifier(),
                'GBC' : GradientBoostingClassifier(),
                'QDA' : QuadraticDiscriminantAnalysis(),
                'HGBT' : HistGradientBoostingClassifier(),
                'ridgeCV' : RidgeClassifierCV(),
                'ridge' : RidgeClassifier(),
                'ABC': AdaBoostClassifier(),
                'ETC' : ExtraTreesClassifier(),
                'KNC' : KNeighborsClassifier(),
                'BC' : BaggingClassifier(),
                'berno' : BernoulliNB(),
                'LDA' : LinearDiscriminantAnalysis(),
                'gauss' : GaussianNB(),
                'nusvc' : NuSVC(),
                'DTC' : DecisionTreeClassifier(),
                'NC' : NearestCentroid()
              }
    
    nombres = ['linearsvc', 'sgdc', 'mlpc', 'percept',
               'LogReg', 'LogistReg',\
               'svc', 'CCCV', 'PAC',
               'LP', 'LS',
               'rfc', 'GBC', 'QDA', 'HGBT',\
               'ridgeCV', 'ridge', 'ABC', 'ETC',
               'KNC', 'BC', 'berno', 'LDA',\
               'gauss', 'nusvc', 'DTC', 'NC'
              ]
    
    accuracy = []
    #precision = []
    #recall = []
    F1_list = []
    
    resumen_modelos = pd.DataFrame()

    for m in modelos:

        mod = modelos[m]
        mod.fit(X_train, y_train)

        y_pred = mod.predict(X_test)
        accu = acc(y_test, y_pred)
        
       # y_pred = mod.predict(X_test)
        #precis = prec(X_test, y_test)

        #y_pred = mod.predict(X_train) 
        #reca = rec(X_train, y_train)
        
        y_pred = mod.predict(X_test) 
        F1 = f1(y_test, y_pred)

        accuracy.append(accu)
        #precision.append(precis)
        #recall.append(recal)
        F1_list.append(F1)

    resumen_modelos['Modelo'] = nombres
    resumen_modelos['ACC'] = accuracy
    #resumen_modelos['precision'] = precision
    #resumen_modelos['recall'] = recall
    resumen_modelos['F1'] = F1_list
    
    dict_errores = dict(zip(nombres, accuracy))
    best = list(dict_errores.keys())[list(dict_errores.values()).index(max(accuracy))] 
    
    modelo = modelos[best]
    
    modelo.fit(X_train, y_train)
    
    y_pred = modelo.predict(X_test)
    acc_test = modelo.score(X_test, y_test)
    y_pred = modelo.predict(X_train) 
    acc_train = modelo.score(X_train, y_train)
    
    accuracy = max(accuracy)
    #precision = round(precis, 4)
    #recall = round(recal, 4)
    F1 = round(F1, 4)
    
    if acc_train > (1.15*acc_test):
        print(f'Best Model: {best}, acc = {accuracy}, acc_train = {acc_train}, acc_test = {acc_test}, OVERFITING (modifica datos)')
    
    elif acc_train > acc_test:
        print(f'Best Model: {best}, acc = {accuracy}, acc_train = {acc_train}, acc_test = {acc_test}, LO NORMAL')
    
    elif acc_train < acc_test:
        print(f'Best Model: {best}, acc = {accuracy}, acc_train = {acc_train}, acc_test = {acc_test}, UNDERFITING (dame más datos)')
        
    return resumen_modelos

# %%
machine_learning()
# Out:
# Best Model: ETC, acc = 0.8414634146341463, acc_train = 1.0, acc_test = 0.8451219512195122, OVERFITING (modifica datos)
#        Modelo       ACC        F1
# 0   linearsvc  0.806098  0.826609
# 1        sgdc  0.791463  0.789149
# 2        mlpc  0.815854  0.830527
# 3     percept  0.762195  0.799589
# 4      LogReg  0.806098  0.823920
# 5   LogistReg  0.806098  0.823920
# 6         svc  0.829268  0.845133
# 7        CCCV  0.809756  0.827815
# 8         PAC  0.767073  0.804903
# 9          LP  0.731707  0.751131
# 10         LS  0.736585  0.756757
# 11        rfc  0.837805  0.848000
# 12        GBC  0.824390  0.839644
# 13        QDA  0.782927  0.814583
# 14       HGBT  0.820732  0.836848
# 15    ridgeCV  0.798780  0.826498
# 16      ridge  0.798780  0.826498
# 17        ABC  0.812195  0.828125
# 18        ETC  0.841463  0.850917
# 19        KNC  0.776829  0.802589
# 20         BC  0.808537  0.818076
# 21      berno  0.765854  0.787140
# 22        LDA  0.798780  0.826498
# 23      gauss  0.773171  0.805846
# 24      nusvc  0.825610  0.842337
# 25        DTC  0.710976  0.722807
# 26         NC  0.764634  0.794462

# %%
ETC.fit(X_train, y_train)
# Out:
# ExtraTreeClassifier()

# %%
y_pred = ETC.predict(X_test)

# %%
indices = list(X_test.index)

# %%
probab = spain_hit_or_not_norm.loc[indices].reset_index(drop=True)

# %%
pred = pd.Series(y_pred)

# %%
pred_test=pd.DataFrame(y_test).reset_index(drop=True)

# %%
probab['prediccion'] = pred.round(decimals = 0)

# %%
probab['fallo'] = probab['top_hit'] - probab['prediccion']
probab[probab['fallo']!=0]
# Out:
#      artist_name    energy  danceability  loudness  acousticness  speechiness  \
# 1      -0.459361  0.446829     -1.925853  0.625954     -0.776713    -0.555565
# 2       0.177089 -0.944412     -1.125962 -0.550029      1.533026     0.893254
# 4       0.350844 -0.687567      1.024102  0.207190      0.877569    -0.494521
# 11      0.956058 -0.893043      0.110750  0.049523     -0.157189     0.978251
# 12     -0.486693  1.097501      0.927661  0.675497     -0.906474    -0.465931
# ..           ...       ...           ...       ...           ...          ...
# 802    -1.615124 -0.708971      1.546017  0.295149      1.496427    -0.553247
# 803     0.770589  0.095808     -0.808274  0.257080     -0.536490    -0.551701
# 810    -0.377364  0.789288      0.002963  0.735991     -0.647951     0.390997
# 811     0.944344  0.797849      0.320651 -0.067989     -0.237042    -0.475976
# 815    -0.066948 -0.435004      0.939007 -0.193670     -0.406729    -0.295164
#
#      liveness   valence     tempo  duration  top_hit  prediccion  fallo
# 1    2.421514 -0.418654  1.356671  1.199084        1           0      1
# 2   -0.984741 -0.835374  1.745650  0.187040        0           1     -1
# 4    0.841057  1.278807 -0.859868 -0.067260        1           0      1
# 11  -0.454119  0.150989  0.215733 -1.244540        1           0      1
# 12   0.726945  0.946197 -0.127715  1.974289        0           1     -1
# ..        ...       ...       ...       ...      ...         ...    ...
# 802 -0.442708  0.888850 -0.243132 -0.348865        1           0      1
# 803 -0.658380 -0.579225  1.629719 -0.265309        0           1     -1
# 810 -0.465530  0.334499  1.913680 -0.416366        0           1     -1
# 811 -0.661233 -0.166329 -0.292905  1.722450        0           1     -1
# 815  0.093621  0.835326 -0.755499  0.492434        1           0      1
#
# [219 rows x 13 columns]

# %%
datos_spotipy_week_1_sp = pd.read_csv('../Proyecto-FInal-Spotify/CSV_full/data_week_9DEC_SPAIN.csv')

# %%
datos_spotipy_week_1_sp.head()
# Out:
#         artist_name                                         track_name  \
# 0     Maria Becerra                               LA NENA DE ARGENTINA
# 1          Anuel AA                                         La Máquina
# 2           Ptazeta                                          Mala Mala
# 3           KAROL G  La Vida Es Una (From Puss in Boots: The Last W...
# 4  Lennis Rodriguez                                            Infeliz
#
#    energy  danceability  loudness  acousticness  speechiness  liveness  \
# 0   0.580         0.531    -4.688        0.0984       0.1880    0.1010
# 1   0.775         0.799    -5.869        0.0308       0.0770    0.3090
# 2   0.898         0.797    -4.617        0.0415       0.0414    0.2660
# 3   0.777         0.819    -7.156        0.0708       0.0513    0.0973
# 4   0.838         0.772    -4.425        0.0261       0.1070    0.0758
#
#    valence    tempo  duration
# 0    0.887  169.865    151.99
# 1    0.605   95.027    296.91
# 2    0.667  120.043    152.00
# 3    0.625  109.979    189.84
# 4    0.874  136.166    172.94

# %%
datos_spotipy_week_1_sp_names = datos_spotipy_week_1_sp.copy()

# %%
datos_spotipy_week_1_sp_norm = datos_spotipy_week_1_sp.copy()

# %%
datos_spotipy_week_1_sp_norm['artist_name']=LabelEncoder().fit_transform(datos_spotipy_week_1_sp_norm['artist_name'])

# %%
datos_spotipy_week_1_sp_norm[['energy','danceability','loudness','acousticness','speechiness','liveness',\
                  'valence','tempo','duration',
                    'artist_name']] = scaler.fit_transform(datos_spotipy_week_1_sp_norm[['energy',\
                    'danceability','loudness','acousticness','speechiness','liveness',\
                  'valence','tempo','duration','artist_name']])

# %%
datos_spotipy_week_1_sp_norm.drop(['track_name'],axis=1,inplace=True)

# %%
y_pred = ETC.predict(datos_spotipy_week_1_sp_norm)

# %%
pred1 = pd.Series(y_pred)

# %%
datos_spotipy_week_1_sp['prediccion'] = pred1.round(decimals = 0)

# %%
datos_spotipy_week_1_sp.prediccion.value_counts()
# Out:
# 0    31
# 1    15
# Name: prediccion, dtype: int64

# %%
datos_spotipy_week_1_sp.head()
# Out:
#         artist_name                                         track_name  \
# 0     Maria Becerra                               LA NENA DE ARGENTINA
# 1          Anuel AA                                         La Máquina
# 2           Ptazeta                                          Mala Mala
# 3           KAROL G  La Vida Es Una (From Puss in Boots: The Last W...
# 4  Lennis Rodriguez                                            Infeliz
#
#    energy  danceability  loudness  acousticness  speechiness  liveness  \
# 0   0.580         0.531    -4.688        0.0984       0.1880    0.1010
# 1   0.775         0.799    -5.869        0.0308       0.0770    0.3090
# 2   0.898         0.797    -4.617        0.0415       0.0414    0.2660
# 3   0.777         0.819    -7.156        0.0708       0.0513    0.0973
# 4   0.838         0.772    -4.425        0.0261       0.1070    0.0758
#
#    valence    tempo  duration  prediccion
# 0    0.887  169.865    151.99           1
# 1    0.605   95.027    296.91           1
# 2    0.667  120.043    152.00           0
# 3    0.625  109.979    189.84           1
# 4    0.874  136.166    172.94           1

# %%
datos_spotipy_week_1_sp_norm.to_csv('../Proyecto-FInal-Spotify/CSV_primeros/datos_spotipy_week_1_sp_norm.csv', index=False)
